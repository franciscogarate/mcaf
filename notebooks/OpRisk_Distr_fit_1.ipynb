# %% [markdown]
# <a href="https://colab.research.google.com/github/franciscogarate/mcaf/blob/master/notebooks/OpRisk_Distr_fit_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

size = 10000
np.random.seed(999)
x = np.arange(size)
y = np.random.lognormal(np.log(10), np.log(2), size)

distrs = ['rayleigh', 'norm', 'lognorm', 'gamma', 'beta', 'exponweib', 'invweibull']

for i in distrs:
    dist = getattr(st, i)
    param = dist.fit(y)
    pdf_fitted = dist.pdf(x, *param[:-2], loc=param[-2], scale=param[-1]) * size
    plt.plot(pdf_fitted, label=i)
    plt.xlim(0,35)
plt.hist(y, bins=range(50), alpha=0.75)
plt.legend(loc='upper right')
plt.show()
