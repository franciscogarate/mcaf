# %% [markdown]
# <a href="https://colab.research.google.com/github/franciscogarate/mcaf/blob/master/notebooks/OpRisk_Intro_Ajuste_distribucion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/franciscogarate/mcaf

# %%
import pandas as pd
import scipy.stats as st

# %%
df = pd.read_csv('mcaf/data/siniestros.csv', sep=';', header=0)
df.head()

# %%
df.hist(column='Importe', bins=40)

# %%
media, desviacion = st.norm.fit(df['Importe'])
print(media)
print(desviacion)
